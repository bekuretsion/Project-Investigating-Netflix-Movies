# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Start coding!
netflix_df = pd.read_csv("netflix_data.csv",index_col =0)
print(netflix_df.head())
print(netflix_df.shape)
netflix_subset=netflix_df[netflix_df["type"] == "Movie"]
print(netflix_subset.head())
netflix_movies = netflix_subset[['title', 'country', 'genre','release_year','duration']]
print(netflix_movies.head())
short_movies = netflix_movies[netflix_movies['duration'] < 60]
print(short_movies.head(20))

print(netflix_movies[['genre']])
colors=[]
for lab,row in netflix_movies.iterrows():
    genre = row['genre']
    if genre== "Dramas":
        colors.append('blue')
    elif genre == "Documentaries":
        colors.append("green")
    elif genre == "Horror Movies":
        colors.append("red")
    elif genre == "Action":
        colors.append("red")  
    else:
        colors.append("gray")
print(colors)
fig = plt.figure(figsize=(12,8))
release_years = [netflix_movies["release_year"]]
durations = [netflix_movies["duration"]]
plt.scatter(release_years, durations,c=colors)
plt.xlabel('Release year')
plt.ylabel('Duration (min)')
plt.title('Movie Duration by Year of Release')
plt.legend()
plt.show()
# Out:
#             type  title           director  \
# show_id
# s1       TV Show     3%                NaN
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
#
#                                                       cast        country  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#                 date_added  release_year  duration  \
# show_id
# s1         August 14, 2020          2020         4
# s2       December 23, 2016          2016        93
# s3       December 20, 2018          2011        78
# s4       November 16, 2017          2009        80
# s5         January 1, 2020          2008       123
#
#                                                description             genre
# show_id
# s1       In a future where the elite inhabit an island ...  International TV
# s2       After a devastating earthquake hits Mexico Cit...            Dramas
# s3       When an army recruit is found dead, his fellow...     Horror Movies
# s4       In a postapocalyptic world, rag-doll robots hi...            Action
# s5       A brilliant group of students become card-coun...            Dramas
# (7787, 10)
#           type  title           director  \
# show_id
# s2       Movie   7:19  Jorge Michel Grau
# s3       Movie  23:59       Gilbert Chan
# s4       Movie      9        Shane Acker
# s5       Movie     21     Robert Luketic
# s7       Movie    122    Yasir Al Yasiri
#
#                                                       cast        country  \
# show_id
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# s7       Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#                 date_added  release_year  duration  \
# show_id
# s2       December 23, 2016          2016        93
# s3       December 20, 2018          2011        78
# s4       November 16, 2017          2009        80
# s5         January 1, 2020          2008       123
# s7            June 1, 2020          2019        95
#
#                                                description          genre
# show_id
# s2       After a devastating earthquake hits Mexico Cit...         Dramas
# s3       When an army recruit is found dead, his fellow...  Horror Movies
# s4       In a postapocalyptic world, rag-doll robots hi...         Action
# s5       A brilliant group of students become card-coun...         Dramas
# s7       After an awful accident, a couple admitted to ...  Horror Movies
#          title        country          genre  release_year  duration
# show_id
# s2        7:19         Mexico         Dramas          2016        93
# s3       23:59      Singapore  Horror Movies          2011        78
# s4           9  United States         Action          2009        80
# s5          21  United States         Dramas          2008       123
# s7         122          Egypt  Horror Movies          2019        95
#                                                      title         country  \
# show_id
# s36                                              #Rucker50   United States
# s56                    100 Things to do Before High School   United States
# s68      13TH: A Conversation with Oprah Winfrey & Ava ...             NaN
# s102                                     3 Seconds Divorce          Canada
# s147                                        A 3 Minute Hug          Mexico
# s163     A Christmas Special: Miraculous: Tales of Lady...          France
# s172                            A Family Reunion Christmas   United States
# s178                       A Go! Go! Cory Carson Christmas   United States
# s179                       A Go! Go! Cory Carson Halloween             NaN
# s180                     A Go! Go! Cory Carson Summer Camp             NaN
# s182                A Grand Night In: The Story of Aardman  United Kingdom
# s201                               A Love Song for Latasha   United States
# s221                            A Russell Peters Christmas          Canada
# s234                                 A StoryBots Christmas   United States
# s238                                A Tale of Two Kitchens   United States
# s243                               A Trash Truck Christmas             NaN
# s248                               A Very Murray Christmas   United States
# s286                                  Abominable Christmas   United States
# s296                                    Across Grace Alley   United States
# s306                   Adam Devine: Best Time of Our Lives   United States
#
#                  genre  release_year  duration
# show_id
# s36      Documentaries          2016        56
# s56      Uncategorized          2014        44
# s68      Uncategorized          2017        37
# s102     Documentaries          2018        53
# s147     Documentaries          2019        28
# s163     Uncategorized          2016        22
# s172     Uncategorized          2019        29
# s178          Children          2020        22
# s179          Children          2020        22
# s180          Children          2020        21
# s182     Documentaries          2015        59
# s201     Documentaries          2020        20
# s221          Stand-Up          2011        44
# s234          Children          2017        26
# s238     Documentaries          2019        30
# s243          Children          2020        28
# s248          Comedies          2015        57
# s286          Children          2012        44
# s296            Dramas          2013        24
# s306          Stand-Up          2019        59
#                  genre
# show_id
# s2              Dramas
# s3       Horror Movies
# s4              Action
# s5              Dramas
# s7       Horror Movies
# ...                ...
# s7782         Children
# s7783           Dramas
# s7784           Dramas
# s7785    Documentaries
# s7787    Documentaries
#
# [5377 rows x 1 columns]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ['blue', 'red', 'red', 'blue', 'red', 'blue', 'red', 'red', 'blue', 'green', 'gray', 'blue', 'blue', 'gray', 'gray', 'blue', 'red', 'blue', 'blue', 'green', 'red', 'green', 'green', 'blue', 'blue', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'red', 'gray', 'blue', 'red', 'blue', 'blue', 'gray', 'gray', 'red', 'green', 'blue', 'gray', 'green', 'blue', 'blue', 'blue', 'red', 'red', 'green', 'gray', 'red', 'red', 'green', 'red', 'gray', 'blue', 'blue', 'red', 'red', 'gray', 'gray', 'green', 'gray', 'gray', 'blue', 'gray', 'red', 'red', 'red', 'blue', 'red', 'green', 'gray', 'red', 'blue', 'blue', 'blue', 'gray', 'green', 'gray', 'gray', 'red', 'blue', 'blue', 'blue', 'gray', 'green', 'gray', 'gray', 'gray', 'blue', 'red', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'blue', 'red', 'red', 'blue', 'red', 'gray', 'blue', 'gray', 'blue', 'gray', 'blue', 'gray', 'green', 'gray', 'gray', 'blue', 'blue', 'blue', 'red', 'gray', 'gray', 'gray', 'red', 'blue', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'blue', 'green', 'blue', 'gray', 'red', 'blue', 'gray', 'blue', 'gray', 'gray', 'gray', 'gray', 'green', 'green', 'gray', 'red', 'blue', 'gray', 'gray', 'green', 'gray', 'blue', 'green', 'green', 'blue', 'green', 'blue', 'gray', 'gray', 'blue', 'blue', 'green', 'green', 'blue', 'gray', 'blue', 'blue', 'blue', 'blue', 'green', 'gray', 'gray', 'gray', 'gray', 'blue', 'green', 'blue', 'gray', 'gray', 'gray', 'blue', 'blue', 'blue', 'blue', 'gray', 'blue', 'blue', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'gray', 'gray', 'blue', 'red', 'green', 'gray', 'gray', 'gray', 'blue', 'red', 'red', 'blue', 'gray', 'gray', 'gray', 'red', 'blue', 'gray', 'blue', 'blue', 'blue', 'blue', 'gray', 'red', 'gray', 'blue', 'blue', 'red', 'green', 'blue', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'gray', 'blue', 'blue', 'blue', 'red', 'red', 'gray', 'red', 'red', 'blue', 'gray', 'gray', 'blue', 'red', 'gray', 'gray', 'gray', 'blue', 'red', 'red', 'blue', 'gray', 'gray', 'gray', 'blue', 'green', 'green', 'green', 'green', 'blue', 'blue', 'blue', 'red', 'blue', 'gray', 'blue', 'gray', 'red', 'blue', 'green', 'blue', 'gray', 'blue', 'gray', 'red', 'gray', 'gray', 'blue', 'gray', 'gray', 'red', 'gray', 'gray', 'gray', 'blue', 'blue', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'green', 'blue', 'red', 'gray', 'gray', 'gray', 'green', 'red', 'gray', 'gray', 'green', 'red', 'gray', 'gray', 'green', 'blue', 'gray', 'red', 'blue', 'gray', 'gray', 'gray', 'green', 'red', 'gray', 'red', 'blue', 'red', 'gray', 'gray', 'blue', 'gray', 'blue', 'blue', 'gray', 'blue', 'blue', 'gray', 'gray', 'gray', 'green', 'green', 'red', 'gray', 'gray', 'green', 'green', 'blue', 'gray', 'red', 'blue', 'blue', 'green', 'green', 'red', 'blue', 'green', 'green', 'green', 'green', 'green', 'gray', 'red', 'blue', 'blue', 'green', 'green', 'gray', 'gray', 'blue', 'blue', 'gray', 'gray', 'blue', 'green', 'gray', 'gray', 'green', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'gray', 'blue', 'blue', 'blue', 'blue', 'gray', 'gray', 'gray', 'gray', 'blue', 'gray', 'blue', 'blue', 'gray', 'red', 'gray', 'red', 'red', 'green', 'green', 'blue', 'red', 'blue', 'red', 'gray', 'gray', 'gray', 'gray', 'blue', 'red', 'blue', 'blue', 'gray', 'red', 'red', 'red', 'gray', 'blue', 'blue', 'gray', 'blue', 'blue', 'red', 'gray', 'gray', 'gray', 'gray', 'gray', 'red', 'green', 'blue', 'green', 'blue', 'green', 'red', 'red', 'red', 'red', 'blue', 'gray', 'gray', 'blue', 'gray', 'gray', 'green', 'gray', 'red', 'gray', 'gray', 'gray', 'gray', 'blue', 'blue', 'red', 'gray', 'blue', 'blue', 'red', 'green', 'red', 'red', 'gray', 'blue', 'red', 'green', 'blue', 'green', 'blue', 'blue', 'gray', 'green', 'gray', 'green', 'blue', 'green', 'red', 'gray', 'red', 'blue', 'gray', 'red', 'blue', 'red', 'red', 'green', 'red', 'gray', 'blue', 'gray', 'blue', 'green', 'blue', 'blue', 'gray', 'gray', 'gray', 'blue', 'blue', 'red', 'r ...
